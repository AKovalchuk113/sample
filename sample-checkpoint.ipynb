# %%
from PIL import Image
from pytesseract import pytesseract

# %%
# Defining paths to tesseract.exe
# and the image we would be using
path_to_tesseract = r"C:\Users\user\Tesseract\tesseract.exe"
image_path = r"C:\Users\user\Text_mining\Sample.png"
  
# Opening the image & storing it in an image object
img = Image.open(image_path)
  
# Providing the tesseract executable
# location to pytesseract library
pytesseract.tesseract_cmd = path_to_tesseract
  
# Passing the image object to image_to_string() function
# This function will extract the text from the image
text = pytesseract.image_to_string(img)
  
# Displaying the extracted text
print(text[:-1])
# Out:
# black
#
# @ roy
#
# wiitesmoke
#
# @ rosybrown
#
# @ fredrick
# red
#
# © darksaimon
#
# @ sienna
#
# @ sandyorown
#
# 5 bisaue
#
# @ton
#
# © moccasin
# Aloralwnite
#
# @ oot
# darkkhaki
#
# * lightgoldenrodyeliow
#
# © olvesrap
# chartreuse
#
# palegreen
#
# @ darkgreen
#
# @seogreen
# mediumspringgreen
#
# @igntseagreen
#
# © paleturquotse
#
# @ darkcyan
# darkturquoise
# deepskyblue
# aliceblue
#
# @ slategray
#
# @ royalbiue
# navy
#
# @ dive
#
# @ mediumpurple
# darkorchia
#
# © plum
#
# em
# mediumvioietred
#
# Gpatevioietred
#
# @ grey
# > lightaray
# @ lightcorai
# @ maroon
# mistyrose
# @ coral
# seashell
# © peachputt
# @ darkorange
# navajowhite
# orange
# @ darkgoldenrod
# ® lemonchiffon
# ivory
# olive
# @ yellowareen
#
# mediumseagreen
#
# ‘mediumaquamarine
#
# Q mesiumturquoise
# darkslategray
#
# c
#
# @ caderbiue
#
# & skyblue
# dodgerblue
#
# @ siategrey
# ghostvite
#
# © arkdive
#
# @ siateblue
#
# @rebeccapurple
# darkviolet
#
# © violet
#
# @ fuchsia
# deeppink
#
# @ crimson
#
# cimgray
# G varkaray
# > lightarey
#
# white
# @ indianred
# © corkred
#
# salmon
# @ vrangered
# @ chocolate
#
# peru
# burlywood
# blanchedalmond
# Owheat
# @ seldenroa
# O khaki
#
# beige
#
# y
# © darkolivegreen
# honeydew
# forestareen
# @ green
# springareen
# aquamarine
# darkslategrey
# aqua
# S powderblue
# @ lightskyblue
# @ lightsiategray
# Olightstee!biue
# lavender
# mediumblue
# @varksiatedlue
# @ dlueviolet
# ‘mediumarchid
# purple
# @ magenta
# hotpink
# > pink
#
# dimgrey
# @ darkgrey
# gainsboro
#
# a
#
# tomato
#
# @ightsalmon
#
# @ sacalebrown
# linen
#
# Santiquewnite
#
# © papayawihip
# » oldlace
# cornsilk
#
# (© palegoldenrod
# > lightyellow
#
# yellow
#
# Ogreenyetiow
# darkseagreen
#
# @ limegreen
#
# @ lime
# mintcream
#
# @ turquoise
# lighteyan
#
# @ teal
#
# gan
#
# © lightblue
#
# @ steeibiue
# lightslategrey
#
# @ comnfiowerolue
#
# @ mignightolue
# b
#
# @ mediumslateblue
#
# @ indigo
#
# ) thistle
# darkmagenta
#
# Borchia
# lavenderblush
#
# © lightpink

# %%
text
# Out:
# 'This path is passed to the open() function to create an image object out of our image. After this,\nwe assigned the pytesseract.tesseract_cmd variable the path stored in path_to_tesseract\n'

# %%
import codecs
import collections
 
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
import matplotlib

# %%
text1 = 'Text mining is the process of extracting information from text data. It involves a variety of tasks such as text categorization, text clustering, concept/entity extraction, sentiment analysis, document summarization, and context-related modeling. It uses information retrieval, lexical analysis, and study of word frequency and pattern recognition techniques to find links and associations. It also uses visualization and natural language processing algorithms and analytical methods.'

# %% [markdown]
# with codecs.open("/content/text1.txt", "r", encoding="utf-8") as f:
#   text1=f.read()
# with codecs.open("/content/text2.txt", "r", encoding="utf-8") as f:
#   text2=f.read()

# %%
def total_tokens(text):
    n = WordPunctTokenizer().tokenize(text)
    return collections.Counter(n), len(n)

# %%
def make_df(counter, size):
    absolute_frequency = np.array([el[1] for el in counter])
    relative_frequency = absolute_frequency / size
    df = pd.DataFrame(data=np.array([absolute_frequency, relative_frequency]).T, index = [el[0] for el in counter], columns=["Absolute frequency", "Relative frequency"])
    df.index.name = "Most common words"
    return df

# %%
text1_counter, text1_size = get_text_counter(text1)
make_df(text1_counter.most_common(10), text1.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 text1_counter, text1_size = get_text_counter(text1)
#       2 make_df(text1_counter.most_common(10), text1.size)
#
# NameError: name 'get_text_counter' is not defined

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm, trange
f = open(r'C:\Users\user\Text_mining\Условия_ДБО.txt', "r", encoding="utf-8")
text = f.read()

# %%
# Out:
# '<Text: ОАО « Сбер Банк » УТВЕРЖДЕНО Протоколом заседания...>'

# %%
test_str = 'Gfg is best for all geeks'
 
# printing original string
print("The original string is : " + (test_str))
 
# initializing K
K = 3
 
# getting splits
temp = test_str.split()
 
# omitting K lengths
res = [ele for ele in temp if len(ele) != K]
 
# joining result
res = ' '.join(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 text[0].items()
#
# AttributeError: 'str' object has no attribute 'items'

# %%
myList = text

for d in myList:
    for k, v in d.items():
        if isinstance(v, list):
            for i, word in enumerate(v):
                v[i] = ' '.join(list(filter(lambda w: len(w)<9, word.split(' '))))

for d in myList: print(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 4
#       1 myList = text
#       3 for d in myList:
# ----> 4     for k, v in d.items():
#       5         if isinstance(v, list):
#       6             for i, word in enumerate(v):
#
# AttributeError: 'str' object has no attribute 'items'

# %%
text
# Out:
# <Text: ОАО « Сбер Банк » УТВЕРЖДЕНО Протоколом заседания...>

# %%
import string
string.punctuation
type(string.punctuation)
spec_chars = string.punctuation + '\n\xa0«»\t—…'
# %%time
text = "".join([ch for ch in text if ch not in spec_chars])
import re
text = re.sub('\n', '', text)
# %%time
text = remove_chars_from_text(text, spec_chars)
# %%time
text = remove_chars_from_text(text, string.digits)
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import word_tokenize
text_tokens = word_tokenize(text)
print(type(text_tokens), len(text_tokens))
text_tokens[:10]
# Out:
# <class 'list'> 15093
# ['ОАО',
#  '«',
#  'Сбер',
#  'Банк',
#  '»',
#  'УТВЕРЖДЕНО',
#  'Протоколом',
#  'заседания',
#  'Правления',
#  'ОАО']

# %%
import nltk
text = nltk.Text(text_tokens)
print(type(text))
text[:10]
# Out:
# <class 'nltk.text.Text'>
# ['ОАО',
#  '«',
#  'Сбер',
#  'Банк',
#  '»',
#  'УТВЕРЖДЕНО',
#  'Протоколом',
#  'заседания',
#  'Правления',
#  'ОАО']

# %%
# %%time
from nltk.probability import FreqDist
fdist = FreqDist(text)
fdist
# Out:
# CPU times: total: 31.2 ms
# Wall time: 34.7 ms
# FreqDist({',': 820, '.': 539, 'в': 521, '(': 337, ')': 334, 'и': 313, 'на': 194, 'СДБО': 190, 'с': 171, 'Клиента': 152, ...})

# %%
fdist
# Out:
# FreqDist({',': 820, '.': 539, 'в': 521, '(': 337, ')': 334, 'и': 313, 'на': 194, 'СДБО': 190, 'с': 171, 'Клиента': 152, ...})

# %%
del fdist['обслуживания']

# %%
fdist
# Out:
# FreqDist({'СДБО': 190, 'Банк': 92, 'виде': 65, 'документов': 64, 'ДБО': 56, 'обслуживание': 56, 'электронном': 56, 'Клиент': 46, 'случае': 44, 'порядке': 40, ...})

# %%
fdist.plot(19,cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# **Облако слов**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text_raw = " ".join(text)

# %%
wordcloud = WordCloud(width = 600, height = 400, background_color = "white", colormap = 'magma').generate(text_raw)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
